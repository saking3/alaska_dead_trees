# %% [markdown]
# # SAM: Predict on Entire Images
#
# Runs dead-tree segmentation on full aerial images using the fine-tuned SAM model. For each input image the pipeline:
# 1. Tiles the image into 256×256 patches with `patchify`
# 2. Derives a bounding-box prompt from each patch's ground-truth mask
# 3. Runs SAM inference patch-by-patch
# 4. Stitches predicted masks back into a full-resolution mask
# 5. Stitches the cropped RGB patches back into a matching RGB image
#
# **Note:** SAM requires a ground-truth mask to generate the bounding-box prompt for each patch. Patches with empty masks (all background) fall back to a default whole-patch bounding box.
#
# Requires a saved, trained SAM model -> see `SAMModel.ipynb`.

# %% [markdown]
# ## Configuration
#
# Update the paths below before running.

# %%
import glob

# --- Input: parallel lists of images and their ground-truth masks ---
# Add one entry per image. Images and masks must be in the same order.
IMAGE_PATHS = [
    '/explore/nobackup/people/sking11/MakingDinoDataset/gliht_1969_rgbi.tif',
    # '/explore/nobackup/people/sking11/MakingDinoDataset/gliht_XXXX_rgbi.tif',
]
MASK_PATHS = [
    '/explore/nobackup/people/sking11/MakingDinoDataset/binarymasks/cleaned_1969_binarymask_500cluster.png',
    # '/explore/nobackup/people/sking11/MakingDinoDataset/binarymasks/cleaned_XXXX_binarymask_500cluster.png',
]

assert len(IMAGE_PATHS) == len(MASK_PATHS), 'IMAGE_PATHS and MASK_PATHS must have the same length'

# --- Output directories (created automatically if they don't exist) ---
OUTPUT_MASK_DIR  = '/explore/nobackup/people/sking11/FullTransectPredictedMasks_SAM'
OUTPUT_IMAGE_DIR = '/explore/nobackup/people/sking11/FullTransectPatchifiedImages_SAM'

# --- Model ---
MODEL_CHECKPOINT_PATH = '/explore/nobackup/people/sking11/sam_model_checkpoint_6400.pth'

# --- Tiling ---
PATCH_SIZE = 256   # tile size in pixels

# %% [markdown]
# ## 1. Imports

# %%
import os
import numpy as np
import torch
from PIL import Image
from patchify import patchify
from tqdm.auto import tqdm
from transformers import SamProcessor, SamModel, SamConfig

# %% [markdown]
# ## 2. Tiling and Stitching Utilities
#
# `tile_image_and_mask` splits an image and its paired ground-truth mask into aligned 256×256 patches and returns the grid dimensions.
#
# `unpatchify` reassembles any flat list of patches (grayscale or RGB) back into a full image. Because `patchify` crops the right/bottom edge to achieve an exact grid, the stitched output may be slightly smaller than the original.

# %%
def tile_image_and_mask(image_path, mask_path, patch_size=256):
    """Load an image and its ground-truth mask, tile both into aligned patches.

    Returns:
        patches_rgb  : np.ndarray (N, H, W, 3)  — raw RGB patches
        patches_mask : np.ndarray (N, H, W)     — binary mask patches (0/1)
        num_rows     : int
        num_cols     : int
    """
    image = np.array(Image.open(image_path).convert('RGB'))
    mask  = np.array(Image.open(mask_path))

    # Normalise mask to 0/1 (handles both 0-255 and already-binary masks)
    if mask.max() > 1:
        mask = (mask / 255.0).astype(np.float32)
    if mask.ndim == 3:
        mask = mask[:, :, 0]  # drop redundant channel if present

    img_grid  = patchify(image, (patch_size, patch_size, 3), step=patch_size)
    mask_grid = patchify(mask,  (patch_size, patch_size),    step=patch_size)
    num_rows, num_cols = img_grid.shape[0], img_grid.shape[1]

    patches_rgb  = img_grid.reshape(-1, patch_size, patch_size, 3)
    patches_mask = mask_grid.reshape(-1, patch_size, patch_size)
    return patches_rgb, patches_mask, num_rows, num_cols


def get_bounding_box(ground_truth_map, margin=10):
    """Derive a bounding-box prompt from a binary mask.
    Falls back to the full patch extent when the mask is empty.
    """
    y_indices, x_indices = np.where(ground_truth_map > 0)
    if len(x_indices) == 0:
        H, W = ground_truth_map.shape
        return [0, 0, W, H]  # whole-patch fallback for empty tiles
    x_min = max(0, np.min(x_indices) - margin)
    x_max = min(ground_truth_map.shape[1], np.max(x_indices) + margin)
    y_min = max(0, np.min(y_indices) - margin)
    y_max = min(ground_truth_map.shape[0], np.max(y_indices) + margin)
    return [x_min, y_min, x_max, y_max]


def unpatchify(patches_list, patch_size, num_rows, num_cols, channels=None):
    """Stitch a flat list of patches into a full image or mask.
    channels=None → grayscale output; channels=3 → RGB output.
    """
    H = W = patch_size
    shape  = (num_rows * H, num_cols * W) if channels is None \
             else (num_rows * H, num_cols * W, channels)
    canvas = np.zeros(shape, dtype=np.float32)
    counts = np.zeros((num_rows * H, num_cols * W), dtype=np.float32)

    for idx, patch in enumerate(patches_list):
        i, j   = divmod(idx, num_cols)
        r0, c0 = i * H, j * W
        if channels is None:
            canvas[r0:r0+H, c0:c0+W] += patch
        else:
            canvas[r0:r0+H, c0:c0+W, :] += patch
        counts[r0:r0+H, c0:c0+W] += 1

    if channels is None:
        canvas = np.divide(canvas, counts, where=counts > 0).astype(np.uint8)
        canvas = np.clip(canvas, 0, 1)
    else:
        canvas = np.divide(canvas, counts[..., None],
                           where=counts[..., None] > 0).astype(np.uint8)
    return canvas

# %% [markdown]
# ## 3. Load Model

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')

model_config = SamConfig.from_pretrained('facebook/sam-vit-base')
processor    = SamProcessor.from_pretrained('facebook/sam-vit-base')
model        = SamModel(config=model_config)
model.load_state_dict(torch.load(MODEL_CHECKPOINT_PATH, weights_only=False))
model.eval()
model.to(device)
print('Model loaded.')

# %% [markdown]
# ## 4. Prediction Pipeline
#
# `predict_image` runs the full tile → prompt → infer → stitch pipeline for one image/mask pair and saves both outputs.
#
# The loop below runs it for every pair in `IMAGE_PATHS` / `MASK_PATHS`.

# %%
os.makedirs(OUTPUT_MASK_DIR,  exist_ok=True)
os.makedirs(OUTPUT_IMAGE_DIR, exist_ok=True)


def predict_image(image_path, mask_path, model, processor, device,
                  patch_size=256):
    """Tile, predict, and stitch one image.

    Args:
        image_path : str  — path to the input GeoTIFF (or any PIL-readable image)
        mask_path  : str  — path to the paired ground-truth binary mask (used for bbox prompts)
        model      : loaded SAM model in eval mode
        processor  : SamProcessor
        device     : torch device
        patch_size : int  — tile size in pixels

    Saves:
        <OUTPUT_MASK_DIR>/<stem>_mask.png   — binary predicted mask (0/255)
        <OUTPUT_IMAGE_DIR>/<stem>_image.png — cropped RGB image matching the mask
    """
    stem = os.path.splitext(os.path.basename(image_path))[0]
    print(f'\nProcessing: {stem}')

    # 1. Tile image and mask together
    patches_rgb, patches_mask, num_rows, num_cols = tile_image_and_mask(
        image_path, mask_path, patch_size
    )
    n_patches = len(patches_rgb)
    print(f'  Grid: {num_rows} rows × {num_cols} cols = {n_patches} patches')

    # 2. Run SAM inference patch-by-patch
    predicted_patches = []
    for idx in tqdm(range(n_patches), desc='  Predicting', leave=False):
        patch_img  = Image.fromarray(patches_rgb[idx])   # PIL for processor
        patch_mask = patches_mask[idx]                   # (H, W) float 0/1
        prompt     = get_bounding_box(patch_mask)

        inputs = processor(patch_img, input_boxes=[[prompt]], return_tensors='pt')
        inputs = {k: v.to(device) for k, v in inputs.items()}

        with torch.no_grad():
            outputs = model(**inputs, multimask_output=False)

        seg_prob = torch.sigmoid(outputs.pred_masks.squeeze(1)).cpu().numpy().squeeze()
        predicted_patches.append((seg_prob > 0.5).astype(np.uint8))

    # 3. Stitch mask and RGB
    full_mask  = unpatchify(predicted_patches,    patch_size, num_rows, num_cols, channels=None)
    full_image = unpatchify(list(patches_rgb),    patch_size, num_rows, num_cols, channels=3)

    # 4. Save outputs
    mask_out  = os.path.join(OUTPUT_MASK_DIR,  f'{stem}_mask.png')
    image_out = os.path.join(OUTPUT_IMAGE_DIR, f'{stem}_image.png')
    Image.fromarray((full_mask * 255).astype(np.uint8), mode='L').save(mask_out)
    Image.fromarray(full_image).save(image_out)
    print(f'  Saved mask  → {mask_out}')
    print(f'  Saved image → {image_out}')

# %%
for image_path, mask_path in zip(IMAGE_PATHS, MASK_PATHS):
    predict_image(image_path, mask_path, model, processor, device,
                  patch_size=PATCH_SIZE)

print('\nAll images processed.')
